# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import QuantileTransformer
from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score, silhouette_samples


# Set a seaborn style for attractive visuals
sns.set_style("whitegrid")
sns.set_theme()

# %%
# loading Dataset

TABLE_NAME = 'workspace.e_commerce.e_commerce_clean_dataset'

print(f'{'=' * 10} Dataset is loading........')
df = spark.table(TABLE_NAME).toPandas()
print(f'{'=' * 10} Dataset is loaded successful')
# Out:
# ========== Dataset is loading........
# ========== Dataset is loaded successful

# %%
# Shape of the dataset
print(f'Shape of the dataset: {df.shape}') #// (Rows, column)
# Out:
# Shape of the dataset: (989571, 13)

# %%
reference_date = df['Invoice_Date'].max()

df_cluster = df.groupby('Customer_ID').agg({
    'Total_price': 'sum',
    'Invoice': 'nunique',
    'Invoice_Date': lambda x: (reference_date - x.max()).days
}).reset_index()

# %%
df_cluster.columns = [
    'Customer_ID',
    'Monetary',
    'Frequency',
    'Recency'
]

df_cluster['Monetary_log']  = np.log1p(df_cluster['Monetary'])
df_cluster['Frequency_log'] = np.log1p(df_cluster['Frequency'])

# %%
df_cluster
# Out:
#       Customer_ID    Monetary  Frequency  Recency  Monetary_log  Frequency_log
# 0             0.0  3001843.50       3077        1     14.914737       8.032035
# 1         12346.0    77556.46         12      320     11.258774       2.564949
# 2         12347.0     4696.71          7       34      8.454830       2.079442
# 3         12348.0     2019.40          5       70      7.611051       1.791759
# 4         12349.0     4428.69          4       13      8.396085       1.609438
# ...           ...         ...        ...      ...           ...            ...
# 5856      18283.0     2456.90         21        4      7.807063       3.091042
# 5857      18284.0      461.68          1      426      6.137036       0.693147
# 5858      18285.0      427.00          1      655      6.059123       0.693147
# 5859      18286.0     1296.43          2      471      7.168141       1.098612
# 5860      18287.0     4182.99          7       37      8.339021       2.079442
#
# [5861 rows x 6 columns]

# %%
CLUSTER_FEATURES = df_cluster[['Recency', 'Monetary_log', 'Frequency_log']].copy()
FEATURE_NAMES = CLUSTER_FEATURES.columns
FEATURE_NAMES
# Out:
# Index(['Recency', 'Monetary_log', 'Frequency_log'], dtype='object')

# %%
X7 = CLUSTER_FEATURES

qt = QuantileTransformer(
    n_quantiles = 10,
    output_distribution = 'normal',
    ignore_implicit_zeros = True,
    random_state = 42
    
)
scaled = qt.fit_transform(X7)
X7_scaled = pd.DataFrame(scaled, columns=FEATURE_NAMES, index=CLUSTER_FEATURES.index)
X7_scaled
# Out:
# /databricks/python/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:2732: UserWarning: 'ignore_implicit_zeros' takes effect only with sparse matrix. This parameter has no effect.
#   warnings.warn(
#        Recency  Monetary_log  Frequency_log
# 0    -2.286548      5.199338       5.199338
# 1     0.572580      1.527789       1.220640
# 2    -0.529453      1.184346       0.764710
# 3    -0.139710      0.592288       0.430727
# 4    -1.073988      1.134652       0.139710
# ...        ...           ...            ...
# 5856 -1.701288      0.731684       1.279168
# 5857  0.886257     -0.424794      -5.199338
# 5858  1.772218     -0.485269      -5.199338
# 5859  1.059720      0.289841      -0.430727
# 5860 -0.479506      1.088926       0.764710
#
# [5861 rows x 3 columns]

# %%
k = 4

km7 = KMeans(
    n_clusters = k,
    random_state = 42,
    n_init = 30,
    max_iter = 300
)

labels7 = km7.fit_predict(X7_scaled)
inertial = km7.inertia_

sil_avg_1= silhouette_score(X7_scaled, labels7)

print(f'Inertia: {round(inertial,2)}')
print(f'Silhoutte: {round(sil_avg_1,2)}')
# Out:
# Inertia: 5252.64
# Silhoutte: 0.47

# %%
base_iter7 = X7_scaled.copy()
base_iter7['cluster']= labels7
sizes7 = base_iter7['cluster'].value_counts().sort_index()
sizes7
# Out:
# cluster
# 0    1754
# 1    1639
# 2     852
# 3    1616
# Name: count, dtype: int64

# %%
sizes7 = base_iter7["cluster"].value_counts().sort_index()
FEATURE_NAMES = CLUSTER_FEATURES.columns
means7 = base_iter7.groupby("cluster")[FEATURE_NAMES].mean().round(3)
means7
# Out:
#          Recency  Monetary_log  Frequency_log
# cluster
# 0          0.524        -0.071         -0.058
# 1          0.675        -0.878         -5.199
# 2         -1.029        -0.072         -0.023
# 3         -0.806         0.992          1.025

# %%
# specifing the figure size 
plt.figure(figsize = (8,6))

base_iter7['cluster'].value_counts().sort_index().plot(kind='bar',
                                                       edgecolor = 'black',
                                                       linewidth=1)

plt.title('K-Means Cluster size - Iteration 7 Quantile Transformer normal',
          color = 'red',
          style = 'italic')

ax = plt.gca()
plt.text(0.65, 0.90, 'Note: All values are in thousands',  
        verticalalignment='top',
        fontsize=8,
        transform = ax.transAxes,
        color = 'grey',
        style = 'italic')

plt.xlabel('Cluster', color = 'blue')
plt.ylabel('Users', color = 'blue')
plt.grid(True)
plt.show()

# %%
# scatter plot (No PCA)

# Recency vs Frequency
import seaborn as sns

plt.figure(figsize= (8,6))
sns.scatterplot(
    data = base_iter7,
    x = 'Recency',
    y = 'Frequency_log',
    hue = 'cluster',
    palette = 'tab10',
)

plt.title('K-Means Iteration 7 Quantile Transformer normal Recency vs Frequency',
          color = 'red',
          style = 'italic')
plt.xlabel('Recency', color = 'teal')
plt.ylabel('Frequency', color = 'teal')
plt.show()

# %%
# scatter plot (No PCA)

# Recency vs Monetary
import seaborn as sns

plt.figure(figsize= (8,6))
sns.scatterplot(
    data = base_iter7,
    x = 'Recency',
    y = 'Monetary_log',
    hue = 'cluster',
    palette = 'tab10',
)

plt.title('K-Means Iteration 7 Quantile Transformer normal Recency vs Monetary',
          color = 'red',
          style = 'italic')
plt.xlabel('Recency', color = 'teal')
plt.ylabel('Monetary', color = 'teal')
plt.show()

# %%
# scatter plot (No PCA)

# Frequency vs Monetary
import seaborn as sns

plt.figure(figsize= (8,6))
sns.scatterplot(
    data = base_iter7,
    x = 'Frequency_log',
    y = 'Monetary_log',
    hue = 'cluster',
    palette = 'tab10',
)

plt.title('K-Means Iteration 7 Quantile Transformer normal Frequency vs Monetary',
          color = 'red',
          style = 'italic')
plt.xlabel('Recency', color = 'teal')
plt.ylabel('Monetary', color = 'teal')
plt.show()

# %%
# silhouette Plot

sil_values_1 = silhouette_samples(X7_scaled, labels7)
sil_avg_1 = silhouette_score(X7_scaled, labels7)
plt.figure(figsize= (7,6))

y_lower = 0

vals0 = sil_values_1[labels7 == 0]
vals0.sort()
size0 = vals0.shape[0]

y_upper = y_lower + size0

plt.fill_betweenx(
    np.arange(y_lower, y_upper),    # vertical span
    0,                              # left boundary (silhoutte = 0)
    vals0,                          # right boundary (actual silhoutte values)
    alpha = 0.8
)
plt.text(
    -0.05,
    y_lower + 0.5 * size0,  # slightly left of zero
    'Cluster 0'             # vertically centered
)

y_lower = y_upper

# Cluster 1
vals1 = sil_values_1[labels7==1]
vals1.sort()
size1 = vals1.shape[0]

y_upper = y_lower + size1

plt.fill_betweenx(
    np.arange(y_lower, y_upper),
    0,
    vals1,
    alpha = 0.8
    )
plt.text(-0.05,
         y_lower + 0.5 * size1, 'Cluster 1')

y_lower = y_upper

# cluster 2
vals2 = sil_values_1[labels7 == 2]
vals2.sort()

size2 = vals2.shape[0]
y_upper = y_lower + size2
plt.fill_betweenx(np.arange(y_lower, y_upper), 0, vals2, alpha = 0.8)
plt.text(-0.05, y_lower + 0.5 * size2, 'Cluster 2')

y_lower = y_upper

# cluster 3
vals3 = sil_values_1[labels7 == 3]
vals3.sort()
size3 = vals3.shape[0]
y_upper = y_lower + size3
plt.fill_betweenx(np.arange(y_lower, y_upper), 0, vals3, alpha = 0.8)
plt.text(-0.05, y_lower + 0.5 * size3, 'Cluster 3')

y_lower = y_upper

plt.axvline(
    x= sil_avg_1,
    color = 'red',
    linestyle = '--',
    label =f"Avg silhouette = {sil_avg_1:.2f}"
)

plt.title('silhouette plot (k = 4) - K-Means Iteration 7 Quantile Transformer normal', color = 'red', style = 'italic')
plt.xlabel('silhouette coefficient', color = 'purple')
plt.ylabel('Sample index (grouped by cluster)', color = 'purple')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
